# %%
text = "California Executive Order N-12-23 orders California's Government Operations Agency"
text1 = "California Senate Bill 1288 requires the Superintendent of Public Instruction"
patterns = [
    {
    "pattern": "California Senate Bill 1288",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "Superintendent of Public Instruction",
    "label": "ACTOR"
    },
    {
    "pattern": "report",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "working group",
    "label": "ACTOR"
    },
    {
    "pattern": "Generative AI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "California Cybersecurity Integration Center",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "energy infrastructure",
    "label": "DOMAIN"
    },
    {
    "pattern": "Governor",
    "label": "ACTOR"
    },
    {
    "pattern": "public",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "California",
    "label": "GEOGRAPHIC"
    },
    {
    "pattern": "training guidelines",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "guidelines",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "pilot project infrastructure",
    "label": "REQUIREMENT"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "Governor",
    "label": "ACTOR"
    },
    {
    "pattern": "UC Berkeley",
    "label": "ACTOR"
    },
    {
    "pattern": "Stanford",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "civil society",
    "label": "ACTOR"
    },
    {
    "pattern": "academia",
    "label": "ACTOR"
    },
    {
    "pattern": "industry experts",
    "label": "ACTOR"
    },
    {
    "pattern": "guidelines",
    "label": "LEGAL_SOURCE"
    }
]

colors = {
    "ACTOR": "#D6E4FF",            # very light blue
    "LEGAL_SOURCE": "#FFE0E0",       # very light red
    "DOMAIN": "#E8D9FF",           # pale violet
    "RISK": "#FFF4CC",             # light cream/amber
    "LIFECYCLE_STAGE": "#DFF7E8",  # pale green
    "TECHNOLOGY": "#FDE6F2",       # soft pink
    "REQUIREMENT": "#DFF6F3",       # pale teal
    "DATE": "#FFB366"
}

options = {
    "ents": [
        "ACTOR",
        "LEGAL_SOURCE",
        "DOMAIN",
        "RISK",
        "LIFECYCLE_STAGE",
        "TECHNOLOGY",
        "REQUIREMENT",
        "DATE"
    ],
    "colors": colors,
    "font": "Calibri"
}

# %%
import spacy
from spacy import displacy
import deplacy

nlp = spacy.load("en_core_web_sm")

ruler = nlp.add_pipe("entity_ruler", before='ner')
ruler.add_patterns(patterns)
doc = nlp(text1)

displacy.render(doc, style="ent", options=options)

# displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #FFE0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California Senate Bill 1288
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGAL_SOURCE</span>
# </mark>
#  requires the
# <mark class="entity" style="background: #D6E4FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Superintendent of Public Instruction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACTOR</span>
# </mark>
# </div></span>

# %%
deplacy.render(doc)
# Out:
# http://127.0.0.1:5000   HTTP deplacy/2.1
# 127.0.0.1 - - [20/Nov/2025 01:21:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Nov/2025 01:21:38] "GET /conllusvgview.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Nov/2025 01:21:38] "GET /conllusvgedit.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Nov/2025 01:21:38] "GET /favicon.ico HTTP/1.1" 404 -

# %%
import spacy
from spacy import displacy

displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Order N-12-23
# ...

# %% [markdown]
# ('California Executive Order N-12-23', 'emphasize', 'civil society')
# ('California Executive Order N-12-23', 'mandate', 'March 2024')
# ('California Executive Order N-12-23', 'mandate', 'pilot project infrastructure')
# ('California Executive Order N-12-23', 'require', 'California Cybersecurity Integration Center')
# (

# %%
# let us try to see how the other main extractor works and showcase its difference to see if there are any major changes.

text = "California Executive Order N-12-23 orders California's Government Operations Agency and related entities to draft a report for the Governor within 60 days on beneficial uses and risks of Generative AI (GenAI) by the state.\n\nCalifornia Executive Order N-12-23 requires the California Cybersecurity Integration Center and related bodies to perform a risk analysis by March 2024 on GenAI threats to energy infrastructure, brief the Governor on findings, and make public recommendations for actions to guard against GenAI threats when appropriate.\n\nCalifornia Executive Order N-12-23 directs various California departments to issue procurement and training guidelines for GenAI by January 2024.\n\nCalifornia Executive Order N-12-23 instructs relevant agencies to develop guidelines by July 2024 for using GenAI tools with vulnerable communities.\n\nCalifornia Executive Order N-12-23 mandates establishment of GenAI pilot project infrastructure by March 2024.\n\nCalifornia Executive Order N-12-23 urges the Governor's Office to partner with UC Berkeley and Stanford to evaluate GenAI's impact.\n\nCalifornia Executive Order N-12-23 tasks legal counsel to assess GenAI's regulatory impact and recommend updates.\n\nCalifornia Executive Order N-12-23 emphasizes collaboration with civil society, academia, and industry experts in drafting guidelines and conducting analyses."
entities = [
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "California's Government Operations Agency",
    "label": "ACTOR"
    },
    {
    "pattern": "report",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "Governor",
    "label": "ACTOR"
    },
    {
    "pattern": "Generative AI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "California Cybersecurity Integration Center",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "energy infrastructure",
    "label": "DOMAIN"
    },
    {
    "pattern": "Governor",
    "label": "ACTOR"
    },
    {
    "pattern": "public",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "California",
    "label": "GEOGRAPHIC"
    },
    {
    "pattern": "training guidelines",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "guidelines",
    "label": "LEGAL_SOURCE"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "pilot project infrastructure",
    "label": "REQUIREMENT"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "Governor",
    "label": "ACTOR"
    },
    {
    "pattern": "UC Berkeley",
    "label": "ACTOR"
    },
    {
    "pattern": "Stanford",
    "label": "ACTOR"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "GenAI",
    "label": "TECHNOLOGY"
    },
    {
    "pattern": "California Executive Order N-12-23",
    "label": "BILL_NAME"
    },
    {
    "pattern": "civil society",
    "label": "ACTOR"
    },
    {
    "pattern": "academia",
    "label": "ACTOR"
    },
    {
    "pattern": "industry experts",
    "label": "ACTOR"
    },
    {
    "pattern": "guidelines",
    "label": "LEGAL_SOURCE"
    }
]

import spacy
from spacy import displacy
import deplacy
from relationship_extractor import RelationExtractor


nlp = spacy.load("en_core_web_sm") # load the model

# add the entities
ruler = nlp.add_pipe("entity_ruler", before="ner",)
ruler.add_patterns(entities)

# load the extractor and pass arguments
extractor = RelationExtractor(nlp)
doc = nlp(text)

# %%
rels = extractor.extract(doc, parser_type='free')
rels
# Out:
# [('California Executive Order N-12-23', 'develop', 'GenAI tools'),
#  ('California Executive Order N-12-23', 'develop', 'July 2024'),
#  ('California Executive Order N-12-23', 'develop', 'guidelines'),
#  ('California Executive Order N-12-23', 'develop', 'vulnerable communities'),
#  ('California Executive Order N-12-23',
#   'direct',
#   'various California departments'),
#  ('California Executive Order N-12-23', 'draft', '60 days'),
#  ('California Executive Order N-12-23', 'draft', 'GenAI'),
#  ('California Executive Order N-12-23', 'draft', 'Generative AI'),
#  ('California Executive Order N-12-23', 'draft', 'Governor'),
#  ('California Executive Order N-12-23', 'draft', 'beneficial uses'),
#  ('California Executive Order N-12-23', 'draft', 'report'),
#  ('California Executive Order N-12-23', 'draft', 'risks'),
#  ('California Executive Order N-12-23', 'draft', 'the state'),
#  ('California Executive Order N-12-23', 'emphasize', 'academia'),
# ...

# %%
from entity_remapping import *
for sub, verb, obj in rels:
    if verb in verb_map:
        print(f"{sub}:[{verb}:{verb_map.get(verb, 'OTHER')}]:{obj}")
# Out:
# California Executive Order N-12-23:[require:OBLIGATE]:California Cybersecurity Integration Center

# %%
rels = extractor.extract(doc, parser_type='legal')
rels
# Out:
# [(('California Executive Order N-12-23', 'BILL_NAME'),
#   'direct',
#   ('California', 'GEOGRAPHIC')),
#  (('California Executive Order N-12-23', 'BILL_NAME'),
#   'require',
#   ('California Cybersecurity Integration Center', 'ACTOR'))]

# %%
rels = extractor.extract(doc, parser_type='child')
rels
# Out:
# [('California Executive Order N-12-23', 'draft', '60 days'),
#  ('California Executive Order N-12-23', 'draft', 'Generative AI'),
#  ('California Executive Order N-12-23', 'draft', 'Governor'),
#  ('California Executive Order N-12-23', 'draft', 'report'),
#  ('California Executive Order N-12-23', 'emphasize', 'civil society'),
#  ('California Executive Order N-12-23',
#   'require',
#   'California Cybersecurity Integration Center')]
